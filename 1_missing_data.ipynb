# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset2/weather_data.txt',parse_dates=['day'])

# %%
df.head()
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01         32.0        6.0   Rain
# 1 2017-01-04          NaN        9.0  Sunny
# 2 2017-01-05         28.0        NaN   Snow
# 3 2017-01-06          NaN        7.0    NaN
# 4 2017-01-07         32.0        NaN   Rain

# %%
df.dtypes
# Out:
# day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
df.isnull().sum()
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
df.fillna({'temperature':df.temperature.mean(),
          'windspeed':df.windspeed.mean(),
          'event':df.event.value_counts().index[0]},)
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         33.2        9.0   Sunny
# 2 2017-01-05         28.0        8.4    Snow
# 3 2017-01-06         33.2        7.0   Sunny
# 4 2017-01-07         32.0        8.4    Rain
# 5 2017-01-08         33.2        8.4   Sunny
# 6 2017-01-09         33.2        8.4   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
#count missing values in a specfic column
#df.temperature.isnull().sum()
#df[df.temperature.isnull()]
v=df.isnull().sum()

# %%
#for i in v[v!=0].index.tolist():

# %%
v
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
#counting missing values in each column
df.isnull().sum()
df[df.temperature.isnull()]
# Out:
#          day  temperature  windspeed  event
# 1 2017-01-04          NaN        9.0  Sunny
# 3 2017-01-06          NaN        7.0    NaN
# 5 2017-01-08          NaN        NaN  Sunny
# 6 2017-01-09          NaN        NaN    NaN

# %%
#if we want to use day column as index 
df.set_index('day',inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(4)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          4.0        9.0   Sunny
# 2017-01-05         28.0        4.0    Snow
# 2017-01-06          4.0        7.0       4
# 2017-01-07         32.0        4.0    Rain
# 2017-01-08          4.0        4.0   Sunny
# 2017-01-09          4.0        4.0       4
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.temperature.mean()
# Out:
# 33.2

# %%
df.event.value_counts().index[0]
# Out:
# 'Sunny'

# %%
#fill all nan values with a single value ,not a good solution
#so pandas provides an alternative for that
import numpy as np
new_df = df.fillna({
    'temperature':df.temperature.mean(),
    'windspeed':df.windspeed.median(),
    'event':df.event.value_counts().index[0]
})
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         33.2        9.0   Sunny
# 2017-01-05         28.0        8.0    Snow
# 2017-01-06         33.2        7.0   Sunny
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         33.2        8.0   Sunny
# 2017-01-09         33.2        8.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#another method
new_df = df.fillna(method='ffill')
# ffill:means carry forward previous value

new_df2 = df.fillna(method='bfill')
#bfill:means carry forward next value
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df2
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#filling  values with limited copying from previous or next values

new_df = df.fillna(method='ffill',limit=1) # copied only one time
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.interpolate()   # fill intermediate values
# default it uses linear interpolation
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
#if date would have 1/3/2017 then 30 temp. could have a better value ...
#but here date is 1/4/2017 so temp. should have around 29...

# %%
new_df = df.interpolate(method='time')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
#now this solution is a pretty powerful than others

# %%
# drop a row having nan values
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# drop a row having all columns are nan values
new_df = df.dropna(how='all')

new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna(thresh=2) #drop all rows having 2 nan values
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### replace function

# %%
new_df = pd.read_csv('dataset2/weather_data2.txt')

# %% [markdown]
# ### suppose we have some special values instead of nan values

# %%
new_df
# Out:
#          day  temperature  windspeed     event
# 0   1/1/2017           32          6      Rain
# 1   1/4/2017       -99999          9     Sunny
# 2   1/5/2017           28     -99999      Snow
# 3   1/6/2017       -99999          7  No event
# 4   1/7/2017           32     -88888      Rain
# 5  1/11/2017           40         12  No event

# %%
newdf=new_df.replace([-99999,-88888],np.nan)
#df.dtypes

# %%
newdf
# Out:
#          day  temperature  windspeed     event
# 0   1/1/2017         32.0        6.0      Rain
# 1   1/4/2017          NaN        9.0     Sunny
# 2   1/5/2017         28.0        NaN      Snow
# 3   1/6/2017          NaN        7.0  No event
# 4   1/7/2017         32.0        NaN      Rain
# 5  1/11/2017         40.0       12.0  No event

# %%
# we can do same thing with dictionary
new_df = new_df.replace({
    'temperature':-99999,
    'windspeed':[-99999,-88888],
    'event':'No event'
},np.nan)

# %%
new_df
# Out:
#          day  temperature  windspeed  event
# 0   1/1/2017         32.0        6.0   Rain
# 1   1/4/2017          NaN        9.0  Sunny
# 2   1/5/2017         28.0        NaN   Snow
# 3   1/6/2017          NaN        7.0    NaN
# 4   1/7/2017         32.0        NaN   Rain
# 5  1/11/2017         40.0       12.0    NaN

# %%
new_df1 = new_df.replace({
    'temperature':-99999,
    'windspeed':[-99999,-88888],
    'event':'No event'
},np.nan)

# %%
new_df1
# Out:
#          day  temperature  windspeed  event
# 0   1/1/2017         32.0        6.0   Rain
# 1   1/4/2017          NaN        9.0  Sunny
# 2   1/5/2017         28.0        NaN   Snow
# 3   1/6/2017          NaN        7.0    NaN
# 4   1/7/2017         32.0        NaN   Rain
# 5  1/11/2017         40.0       12.0    NaN

# %%
new_df = pd.read_csv('dataset2/weather_data2.txt')

new_df
# Out:
#          day  temperature  windspeed     event
# 0   1/1/2017           32          6      Rain
# 1   1/4/2017       -99999          9     Sunny
# 2   1/5/2017           28     -99999      Snow
# 3   1/6/2017       -99999          7  No event
# 4   1/7/2017           32     -88888      Rain
# 5  1/11/2017           40         12  No event

# %%
new_df = new_df.replace({
    
    -99999:np.nan,
    -88888:np.nan,
    'No event':'Sunny'
})

# %%
new_df
# Out:
#          day  temperature  windspeed  event
# 0   1/1/2017         32.0        6.0   Rain
# 1   1/4/2017          NaN        9.0  Sunny
# 2   1/5/2017         28.0        NaN   Snow
# 3   1/6/2017          NaN        7.0  Sunny
# 4   1/7/2017         32.0        NaN   Rain
# 5  1/11/2017         40.0       12.0  Sunny

# %% [markdown]
# ### Use Regression

# %%
df = pd.read_csv('dataset2/weather_data3.txt')

# %%
df
# Out:
#          day temperature windspeed   event
# 0   1/1/2017         32F      6mph    Rain
# 1   1/4/2017         NaN      9mph   Sunny
# 2   1/5/2017          28       NaN    Snow
# 3   1/6/2017         NaN         7     NaN
# 4   1/7/2017         32C       NaN    Rain
# 5   1/8/2017         NaN       NaN   Sunny
# 6   1/9/2017         NaN       NaN     NaN
# 7  1/10/2017          34         8  Cloudy
# 8  1/11/2017          40        12   Sunny

# %%
new_df = df.replace('[A-Za-z]','',regex=True)

# %%
new_df
# Out:
#          day temperature windspeed event
# 0   1/1/2017          32         6
# 1   1/4/2017         NaN         9
# 2   1/5/2017          28       NaN
# 3   1/6/2017         NaN         7   NaN
# 4   1/7/2017          32       NaN
# 5   1/8/2017         NaN       NaN
# 6   1/9/2017         NaN       NaN   NaN
# 7  1/10/2017          34         8
# 8  1/11/2017          40        12

# %%
new = df.replace({
    'temperature':'[A-Za-z]',
    'windspeed':'[A-Za-z]'
},'',regex=True)

# %%
new
# Out:
#          day temperature windspeed   event
# 0   1/1/2017          32         6    Rain
# 1   1/4/2017         NaN         9   Sunny
# 2   1/5/2017          28       NaN    Snow
# 3   1/6/2017         NaN         7     NaN
# 4   1/7/2017          32       NaN    Rain
# 5   1/8/2017         NaN       NaN   Sunny
# 6   1/9/2017         NaN       NaN     NaN
# 7  1/10/2017          34         8  Cloudy
# 8  1/11/2017          40        12   Sunny
